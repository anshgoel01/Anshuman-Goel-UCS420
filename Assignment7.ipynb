# %%
import numpy as np
import pandas as pd

# Initialize Random Seed (Replace with your roll number)
roll_number = 102317042 # Change this to your roll number
np.random.seed(roll_number)

# Generate Sales Data (12 months, 4 categories)
sales_data = np.random.randint(1000, 5001, size=(12, 4))

# Convert to DataFrame
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df = pd.DataFrame(sales_data, columns=categories, index=months)

df.head()  # Display first 5 rows
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         3040      3625            1732    3297
# Feb         3211      3257            2024    3127
# Mar         3228      3241            4373    3920
# Apr         3253      2505            3443    4711
# May         2021      2464            3379    4616

# %%
# Summary Statistics
df.describe()


# Total sales per category
total_sales_per_category = df.sum()

# Total sales per month
df['Total Sales'] = df.sum(axis=1)

# Average sales growth between consecutive months
df['Growth Rate'] = df['Total Sales'].pct_change() * 100

# Apply Discount
if roll_number % 2 == 0:
    df['Electronics'] = df['Electronics'] * 0.9  # 10% discount
else:
    df['Clothing'] = df['Clothing'] * 0.85  # 15% discount


df.head()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       2736.0      3625            1732    3297        11694          NaN
# Feb       2889.9      3257            2024    3127        11619    -0.641355
# Mar       2905.2      3241            4373    3920        14762    27.050521
# Apr       2927.7      2505            3443    4711        13912    -5.758027
# May       1818.9      2464            3379    4616        12480   -10.293272

# %%
import matplotlib.pyplot as plt

# Line Plot for Monthly Sales Trends
df.drop(columns=['Total Sales', 'Growth Rate']).plot(kind='line', marker='o')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# Boxplot for Sales Distribution
plt.figure(figsize=(8, 5))
sns.boxplot(data=df.drop(columns=['Total Sales', 'Growth Rate']))
plt.title('Sales Distribution by Category')
plt.show()

# %%
array = np.array([[1, -2, 3], [-4, 5, -6]])

# (i) Element-wise absolute value
abs_array = np.abs(array)

# (ii) Percentiles
percentiles = {
    "Flattened": np.percentile(array, [25, 50, 75]),
    "Column-wise": np.percentile(array, [25, 50, 75], axis=0),
    "Row-wise": np.percentile(array, [25, 50, 75], axis=1)
}

# (iii) Mean, Median, Std Dev
stats = {
    "Flattened": (np.mean(array), np.median(array), np.std(array)),
    "Column-wise": (np.mean(array, axis=0), np.median(array, axis=0), np.std(array, axis=0)),
    "Row-wise": (np.mean(array, axis=1), np.median(array, axis=1), np.std(array, axis=1))
}

abs_array, percentiles, stats
# Out:
# (array([[1, 2, 3],
#         [4, 5, 6]]),
#  {'Flattened': array([-3.5, -0.5,  2.5]),
#   'Column-wise': array([[-2.75, -0.25, -3.75],
#          [-1.5 ,  1.5 , -1.5 ],
#          [-0.25,  3.25,  0.75]]),
#   'Row-wise': array([[-0.5, -5. ],
#          [ 1. , -4. ],
#          [ 2. ,  0.5]])},
#  {'Flattened': (-0.5, -0.5, 3.8622100754188224),
#   'Column-wise': (array([-1.5,  1.5, -1.5]),
#    array([-1.5,  1.5, -1.5]),
#    array([2.5, 3.5, 4.5])),
#   'Row-wise': (array([ 0.66666667, -1.66666667]),
#    array([ 1., -4.]),
#    array([2.05480467, 4.78423336]))})

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])


floor_vals = np.floor(a)
ceil_vals = np.ceil(a)
trunc_vals = np.trunc(a)
round_vals = np.round(a)

floor_vals, ceil_vals, trunc_vals, round_vals
# Out:
# (array([-2., -2., -1.,  0.,  1.,  1.,  3.]),
#  array([-1., -1., -0.,  1.,  2.,  2.,  3.]),
#  array([-1., -1., -0.,  0.,  1.,  1.,  3.]),
#  array([-2., -2., -0.,  0.,  2.,  2.,  3.]))

# %%
def swap_list_elements(Lst, pos1, pos2):
    temp = Lst[pos1]
    Lst[pos1] = Lst[pos2]
    Lst[pos2] = temp
    return Lst

Lst = [10, 20, 30, 40, 50]
pos1, pos2 = 1, 3  # Swap elements at index 1 and 3
swap_list_elements(Lst, pos1, pos2)
# Out:
# [10, 40, 30, 20, 50]

# %%
def swap_list_elements(Last, pos1, pos2):
    temp = Last[pos1]
    Last[pos1] = Last[pos2]
    Last[pos2] = temp
    return Last


s = {1,2,3,4,5}
Last = list(s)
last
pos1, pos2 = 1, 3  # Swap elements at index 1 and 3
swap_list_elements(Last, pos1, pos2)
# Out:
# [1, 4, 3, 2, 5]
